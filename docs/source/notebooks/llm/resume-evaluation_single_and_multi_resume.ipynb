# %%
# %pip install boto3==1.34.93 ipython --quiet

# %load_ext autoreload
# %autoreload 2

# %%
# import boto3
import json, re
# %time
# session = boto3.session.Session()
# bedrock_client = session.client(
#     service_name='bedrock-runtime',
#     region_name='eu-west-3',
# )

# # Model id and Claude config
# model_id = "anthropic.claude-3-sonnet-20240229-v1:0"
# claude_config = {
#     'max_tokens': 4096,
#     'temperature': 0, 
#     'anthropic_version': '',
#     'stop_sequences': ['Human:']
# }

# %%
# AO
cdc_json_file_path = f"/workspace/outputs/2023DOS0550696/json/ao/formatted_json_cdc.json"
rec_json_file_path = f"/workspace/outputs/2023DOS0550696/json/ao/formatted_json_rec.json"
# CV
entreprise = "cgi"
cv_json_file_path1 = f"/workspace/outputs/2023DOS0550696/json/{entreprise}/formatted_json_cv.json"
entreprise = "amaris"
cv_json_file_path2 = f"/workspace/outputs/2023DOS0550696/json/{entreprise}/formatted_json_cv.json"
entreprise = "experis_dva"
cv_json_file_path3 = f"/workspace/outputs/2023DOS0550696/json/{entreprise}/formatted_json_cv.json"
entreprise = "experis_jcl"
cv_json_file_path4 = f"/workspace/outputs/2023DOS0550696/json/{entreprise}/formatted_json_cv.json"
entreprise = "neurones_jmb"
cv_json_file_path5 = f"/workspace/outputs/2023DOS0550696/json/{entreprise}/formatted_json_cv.json"
entreprise = "neurones_tko"
cv_json_file_path6 = f"/workspace/outputs/2023DOS0550696/json/{entreprise}/formatted_json_cv.json"
entreprise = "synchrone"
cv_json_file_path7 = f"/workspace/outputs/2023DOS0550696/json/{entreprise}/formatted_json_cv.json"

list_paths_resume = [cv_json_file_path1, cv_json_file_path2, cv_json_file_path3, cv_json_file_path4, cv_json_file_path5, cv_json_file_path6, cv_json_file_path7]

# %%
# Open the JSON file and load its contents
with open(cdc_json_file_path, "r") as file:
    cdc_json_data = json.load(file)

list_resume = []
for path in list_paths_resume:    
    with open(path, "r") as file:
        cv_json_data = json.load(file)
        list_resume.append(cv_json_data)

with open(rec_json_file_path, "r") as file:
    rec_json_data = json.load(file)

# Now you can work with the loaded JSON data
print(cdc_json_data)
print(cv_json_data)

# Add you json inputs here
REQUIREMENTS = cdc_json_data
RESUME = list_resume
# Out:
# {'objectif_de_la_mission': ["La mission objet de cette consultation vise à décharger les équipes SNCF dans trois domaines concernant les services bureautiques et digitaux au sens large : - La gestion courante des sollicitations et demandes ; - L'assistance et le conseil aux utilisateurs ; - La gestion des stocks, de l'approvisionnement à la mise au rebus en passant par la remise en main.", 1], 'duree_de_la_mission': [210, 3], 'nombre_de_profils': [1, 2], 'types_de_profils': [{'type': ['701.E.PAR - Support Méthode, qualité et Sécurité Expert - ouvert à des profils Senior (701.S.PAR)', 2]}], 'taches_et_responsabilites': [{'tache_et_responsabilite': ['Traiter les demandes des agents G&C reçues via le portail interne Digital Office', 1]}, {'tache_et_responsabilite': ["Prendre en charge les déclarations d'incidents ou d'anomalie de fonctionnement bureautique quand les processus standard des porteurs de services ne suffisent pas", 1]}, {'tache_et_responsabilite': ['Alerter / escalader en interne DDT et/ou chez les fournisseurs', 1]}, {'tache_et_responsabilite': ["Assurer le lien avec les différentes assistances et support pour garantir qu'une réponse soit apportée aux utilisateurs", 1]}, {'tache_et_responsabilite': ["Gérer le stock, les dotations et les retours d'équipements PC, tablettes, smartphones pour l'ensemble du siège de G&C", 1]}, {'tache_et_responsabilite': ['Assister le CSIE dans la gestion des commandes : déclenchement du réappro, suivi, relance', 1]}, {'tache_et_responsabilite': ['Assurer le tri des matériels à évacuer (recyclage, collecte SNCF)', 1]}, {'tache_et_responsabilite': ["Assurer physiquement les remises et retours d'équipements", 1]}, {'tache_et_responsabilite': ['Assister les utilisateurs dans la prise en main et le paramétrage des équipements (en particulier smartphone et tablette)', 1]}, {'tache_et_responsabilite': ["Apporter conseil à l'utilisation bureautique et accompagnement sur les outils digitaux", 1]}, {'tache_et_responsabilite': ['Prendre en charge des actions de communication et de pédagogie au nom de la DDT', 1]}, {'tache_et_responsabilite': ['Rédiger des procédures, des tutoriels, des consignes', 1]}, {'tache_et_responsabilite': ['Participer à de mini-projets concernant la gestion du site', 1]}], 'competences_du_profils': [{'competence': ['Personne ayant déjà piloté des parcs bureautiques et/ou des flottes mobiles', 6]}, {'competence': ['Technicien aguerri, autonome dans le diagnostic voire la remédiation de problème bureautique / mobile et même de problème sur les infrastructures (réseau, VPN, habilitations, opérateurs, store, etc…)', 6]}, {'competence': ['Suffisamment expérimenté et autonome pour tenir le service en récurrent et alerter à bon escient', 6]}], 'stack_technique': [{'tache': ['Flottes sous Android et iOS', 6]}, {'tache': ['Parc de PC sous Windows et Mac', 6]}, {'tache': ['Environnement bureautique O365 dans un contexte Active Directory / VPN', 6]}], 'duree_de_la_mission_avec_option': ["630 jours maximum en cas de levée d'option", 3]}
# {'diplomes': [{'niveau_etude': 'Bac+5', 'date_obtention': '2010-01-01', 'diplome': 'Master 2 réseaux et systèmes informatiques', 'competences_acquises': [{'tache': 'N/A'}]}], 'certifications': [{'date_obtention': '2018-01-01', 'certification': 'Formation Devops', 'competences_acquises': [{'tache': 'N/A'}]}, {'date_obtention': '2017-01-01', 'certification': 'Administration infrastructures réseaux', 'competences_acquises': [{'tache': 'N/A'}]}], 'langues_parlees': [{'langue': 'Anglais', 'niveau': 'Technique'}], 'experiences_entreprise': [{'nom_entreprise': ['SNCF', 1], 'duree_experience': ['À nos jours', 1], 'date_debut_experience': ['2023-01-01', 1], 'date_fin_experience': ['N/A', 1], 'nom_poste': ['Consultant Technicien Support Informatique', 1], 'stack_technique': [{'tache': ['ITSM (ARS), environnement bureautique, installation de postes informatiques, installation de logiciels, masterisation et préparation de postes, déménagement de postes, récupération de postes, gestion de parc, migration Windows 10, gestion de salles de crises', 1]}]}, {'nom_entreprise': ['RATP', 2], 'duree_experience': ['10 mois', 2], 'date_debut_experience': ['2022-03-01', 2], 'date_fin_experience': ['2022-12-31', 2], 'nom_poste': ['Consultant Technicien Support Informatique', 2], 'stack_technique': [{'tache': ["Support technique Niveau 2, résolution d'incidents réseaux/matériels/logiciels, installation/paramétrage/configuration matériel informatique, installation applications, installation/paramétrage imprimantes, brassage réseaux, accompagnement utilisateurs, formation utilisateurs, gestion administrative inventions/tickets, suivi dotation matériel, prise en main à distance, résolution problèmes VPN, mise en service et configuration postes, déploiement postes Windows 7 à 10, sauvegarde/transfert données, déblocage comptes Windows, mises à jour/sécurité/gestion mots de passe, déploiement postes/intégration domaines, tablettes/smartphones Android/iPhone", 2]}], 'role': [{'tache': ['Assurer le support technique Niveau 2', 2]}, {'tache': ['Résolution des incidents réseaux, matériels, logiciels', 2]}, {'tache': ['Installation, paramétrage et configuration du matériel informatique (PC, tablette, imprimante…)', 2]}, {'tache': ['Installation des applications spécifiques aux clients', 2]}, {'tache': ['Installation/paramétrage/imprimantes', 2]}, {'tache': ['Brassage réseaux', 2]}, {'tache': ['Accompagnement des utilisateurs au niveau informatique', 2]}, {'tache': ["Formation auprès des utilisateurs sur les bonnes pratiques d'utilisation du matériel", 2]}, {'tache': ['Gestion administrative des inventions/gestion des tickets via Smarti,ITSM, Service Now', 2]}, {'tache': ['Suivi de la dotation de matériel', 2]}, {'tache': ['Prise en main à distance pour la résolution des incidents', 2]}, {'tache': ['Résolution des différents problèmes liés au VPN', 2]}, {'tache': ['Mise en service et configuration des postes', 2]}, {'tache': ["Déploiement des postes informatiques systèmes d'exploitation Windows 7 vers Windows 10, mise à jour des logiciels", 2]}, {'tache': ['Sauvegarde et transfère des données', 2]}, {'tache': ['Déblocage de comptes Windows', 2]}, {'tache': ['Mises à jour, sécurité, gestion des mots de passe du réseau et en local, déploiement postes, intégration aux domaines.', 2]}, {'tache': ['Tablettes, Smartphone Android, IPhone : Mises à jour, sécurité, enrôlement.', 2]}]}, {'nom_entreprise': ['Caisse des Dépôts & Consignations', 3], 'duree_experience': ['2 années, 2 mois', 3], 'date_debut_experience': ['2020-02-01', 3], 'date_fin_experience': ['2022-03-31', 3], 'nom_poste': ['Consultant Technicien Support Informatique', 3], 'stack_technique': [{'tache': ["Support technique Niveaux 2 et 3 junior, résolution d'incidents réseaux/matériels/logiciels, installation/paramétrage/configuration matériel informatique, installation applications, installation/paramétrage imprimantes, brassage réseaux, accompagnement utilisateurs, formation utilisateurs, gestion administrat ...

# %%
CRITERIAS  = rec_json_data['sous_criteres_techniques_et_ponderation']

for critere_json in rec_json_data['sous_criteres_techniques_et_ponderation']:
    print(critere_json['critere'])
# Out:
# ['Qualité de la réponse (Compréhension du besoin, le cas échéant outils et méthodologie proposés)', 1]
# ['Nombre et pertinence des expériences similaires', 1]
# ['Compétences techniques', 1]
# ['Connaissance du domaine fonctionnel', 1]
# ["Expériences similaires en accompagnement au changement, actions pédagogiques illustrant la capacité d'écoute, de reformulation et de synthèse", 1]

# %%
SCALE = {
    0: "Ne répond pas au besoin",
    1: "Ne répond pas suffisamment au besoin",
    2: "Répond partiellement au besoin",
    3: "Répond correctement au besoin",
    4: "Très bonne réponse",
    5: "Réponse au-delà des attentes"
}

# %%
from dag_nao.modules.technical_notation.single_and_multi_resume_comparator.llm_comparator import LLMComparator

llm_comparator = LLMComparator()
formated_json_response_list, score = llm_comparator.call_comparator(requirements=REQUIREMENTS, criterias=CRITERIAS, list_resume=RESUME, scale=SCALE)
# Out:
# CV in process
# CV in process
# CV in process
# CV in process
# CV in process
# CV in process
# CV in process
# {'Qualité de la réponse (Compréhension du besoin, le cas échéant outils et méthodologie proposés)': {'score': 4, 'justification': "Le candidat semble avoir une très bonne compréhension du besoin et des tâches requises grâce à ses expériences pertinentes chez AVANCIAL, SFR et SNCF. Cependant, il manque des informations spécifiques sur les outils et méthodologies utilisés pour la gestion des stocks et des dotations d'équipements."}, 'Nombre et pertinence des expériences similaires': {'score': 4, 'justification': "Avec 6 ans d'expérience très pertinente en tant que Support Méthode, qualité et Sécurité, ainsi que d'autres expériences similaires chez SFR, SNCF, Citroën et Canon, le candidat possède un nombre élevé d'expériences pertinentes pour la plupart des aspects de la mission. Cependant, la gestion des stocks et approvisionnements semble être un point faible."}, 'Compétences techniques': {'score': 3, 'justification': "Le candidat possède de solides compétences techniques en support bureautique, gestion d'incidents et documentation. Néanmoins, son expérience semble davantage axée sur les environnements mainframe et les anciennes versions de Windows. Certains candidats semblent avoir une expérience plus récente sur les flottes mobiles Android/iOS, les parcs de PC sous Windows/Mac récents et les environnements O365/Active Directory/VPN."}, 'Connaissance du domaine fonctionnel': {'score': 3, 'justification': "Le candidat possède une expérience pertinente de 6 ans en tant que Support Méthode, qualité et Sécurité, ainsi que d'autres expériences similaires impliquant la gestion des équipements, le support aux utilisateurs et la rédaction de procédures. Cependant, il semble manquer d'expérience récente sur la gestion de flottes mobiles et la gestion des stocks/approvisionnements."}, "Expériences similaires en accompagnement au changement, actions pédagogiques illustrant la capacité d'écoute, de reformulation et de synthèse": {'score': 3, 'justification': "Le candidat possède une expérience significative dans le support aux utilisateurs, la communication, la documentation et le conseil bureautique, ce qui est pertinent pour l'accompagnement au changement et les actions pédagogiques. Cependant, les informations spécifiques sur les actions pédagogiques réalisées et les capacités de reformulation/synthèse sont limitées dans le CV."}}
# <class 'dict'>
# {'Qualité de la réponse (Compréhension du besoin, le cas échéant outils et méthodologie proposés)': {'score': 4, 'justification': "Le candidat semble avoir une très bonne compréhension du besoin et des tâches requises grâce à ses expériences pertinentes chez AVANCIAL, SFR et SNCF. Cependant, il manque des informations spécifiques sur les outils et méthodologies utilisés pour la gestion des stocks et des dotations d'équipements."}, 'Nombre et pertinence des expériences similaires': {'score': 4, 'justification': "Avec 6 ans d'expérience très pertinente en tant que Support Méthode, qualité et Sécurité, ainsi que d'autres expériences similaires chez SFR, SNCF, Citroën et Canon, le candidat possède un nombre élevé d'expériences pertinentes pour la plupart des aspects de la mission. Cependant, la gestion des stocks et approvisionnements semble être un point faible."}, 'Compétences techniques': {'score': 3, 'justification': "Le candidat possède de solides compétences techniques en support bureautique, gestion d'incidents et documentation. Néanmoins, son expérience semble davantage axée sur les environnements mainframe et les anciennes versions de Windows. Certains candidats semblent avoir une expérience plus récente sur les flottes mobiles Android/iOS, les parcs de PC sous Windows/Mac récents et les environnements O365/Active Directory/VPN."}, 'Connaissance du domaine fonctionnel': {'score': 3, 'justification': "Le candidat possède une expérience pertinente de 6 ans en tant que Support Méthode, qualité et Sécurité, ainsi que d'autres expériences similaires impliquant la gestion des équipements, le support aux utilisateurs et la rédaction de procédures. Cependant, il semble manquer d'expérience récente sur la gestion de flottes mobiles et la gestion des stocks/approvisionnements."}, "Expériences similaires en accompagnement au changement, actions pédagogiques illustrant la capacité d'écoute, de reformulation et de synthèse": {'score': 3, 'justification': "Le candidat possède une expérience significative dans le support aux utilisateurs, la communication, la documentation et le conseil bureautique, ce qui est pertinent pour l'accompagnement au changement et les actions pédagogiques. Cependant, les informations spécifiques sur les actions pédagogiques réalisées et les capacités de reformulation/synthèse sont limitées dans le CV."}}
# {'Qualité de la réponse (Compréhension du besoin, le cas échéant outils et méthodologie proposés)': {'score': 3, 'justification': "Le candidat possède une expérience pertinente en tant que consultant support et AMOA pour des projets de migration de GED, démontrant une bonne compréhension des besoins liés à la gestion de documents et de contenus numériques. Cependant, son CV ne mentionne pas spécifiquement d'expérience avec les environnements techniques demandés ni les méthodologies ou outils utilisés pour la gestion des demandes, des incidents et des stocks d'équipements."}, 'Nombre et pertinence des expériences similaires': {'score': 4, 'justification': "Le candidat possède de nombreuses expériences pertinentes couvrant une grande partie des tâches attendues dans la mission, notamment le support utilisateurs, l'assistance, l'administration, la gestion de projets et de matériels. Ses expériences sont acquises sur des missions de longue durée chez différentes entreprises, ce qui est un atout. Cependant, il manque peut-être un peu d'expérience spécifique sur la gestion des stocks et des équipements."}, 'Compétences techniques': {'score': 2, 'justification': "Le candidat possède une solide expérience dans le support technique, la gestion de parcs bureautiques et la résolution de problèmes, avec une stack technique variée. Cependant, il n'a pas d'expérience spécifique mentionnée avec les flottes mobiles Android/iOS et l'environnement O365/Active Directory/VPN, qui sont des compétences clés requises pour la mission."}, 'Connaissance du domaine fonctionnel': {'score': 3, 'justification': 'Le candidat a une bonne connaissance du domaine fonctionnel de la gestion documentaire et de la messagerie. Cependant, son expérience semble plus limitée dans les aspects spécifiques de la gestion des parcs bureautiques, des flottes mobiles et de la gestion des stocks, qui sont des éléments importants de la mission.'}, "Expériences similaires en accompagnement au changement, actions pédagogiques illustrant la capacité d'écoute, de reformulation et de synthèse": {'score': 2, 'justification': "Le candidat a une expérience significative en support utilisateurs et en formation. Cependant, peu de détails sont fournis sur des actions pédagogiques spécifiques démontrant ses capacités de reformulation, d'écoute et de synthèse dans un contexte d'accompagnement au changement. Son profil semble plus technique que pédagogique."}}
# <class 'dict'>
# {'Qualité de la réponse (Compréhension du besoin, le cas échéant outils et méthodologie proposés)': {'score': 3, 'justification': "Le candidat possède une expérience pertinente en tant que consultant support et AMOA pour des projets de migration de GED, démontrant une bonne compréhension des besoins liés à la gestion de documents et de contenus numériques. Cependant, son CV ne mentionne pas spécifiquement d'expérience avec les environnements techniques demandés ni les méthodologies ou outils utilisés pour la gestion des demandes, des incidents et des stocks d'équipements."}, 'Nombre et pertinence des expériences similaires': {'score': 4, 'justification': "Le candidat possède de nombreuses expériences pertinentes couvrant une grande partie des tâches attendues dans la mission, notamment le support utilisateurs, l'assistance, l'administration, la gestion de projets et de matériels. Ses expériences sont acquises sur des missions de longue durée chez différentes entreprises, ce qui est un atout. Cependant, il manque peut-être un peu d'expérience spécifique sur la gestion des stocks et des équipements."}, 'Compétences techniques': {'score': 2, 'justification': "Le candidat possède une solide expérience dans le support technique, la gestion de parcs bureautiques et la résolution de problèmes, avec une stack technique variée. Cependant, il n'a pas d'expérience spécifique mentionnée avec les flottes mobiles Android/iOS et l'environnement O365/Active Directory/VPN, qui sont des compétences clés requises pour la mission."}, 'Connaissance du domaine fonctionnel': {'score': 3, 'justification': 'Le candidat a une bonne connaissance du domaine fonctionnel de la gestion documentaire et de la messagerie. Cependant, son expérience semble plus limitée dans les aspects spécifiques de la gestion des parcs bureautiques, des flottes mobiles et de la gestion des stocks, qui sont des éléments importants de la mission.'}, "Expériences similaires en accompagnement au changement, actions pédagogiques illustrant la capacité d'écoute, de reformulation et de synthèse": {'score': 2, 'justification': "Le candidat a une expérience significative en support utilisateurs et en formation. Cependant, peu de détails sont fournis sur des actions pédagogiques spécifiques démontrant ses capacités de reformulation, d'écoute et de synthèse dans un contexte d'accompagnement au changement. Son profil semble plus technique que pédagogique."}}
# {'Qualité de la réponse (Compréhension du besoin, le cas échéant outils et méthodologie proposés)': {'score': 3, 'justification': "Le candidat possède une expérience pertinente dans la gestion de parcs bureautiques et de flottes mobiles, ainsi que dans l'utilisation d'outils tels que ServiceNow, SCCM, GLPI, etc. Cependant, son CV ne mentionne pas spécifiquement sa compréhension des besoins de cette mission particulière de la SNCF ni la méthodologie ou les outils qu'il proposerait."}, 'Nombre et pertinence des expériences similaires': {'score': 5, 'justification': "Le candidat possède une expérience significative et pertinente dans la gestion des incidents, du matériel bureautique, de l'assistance aux utilisateurs et de la gestion des flottes mobiles, qui sont des aspects clés de la mission. Son expérience avec les outils ITSM, de déploiement et de gestion des flottes mobiles est un atout majeur. Cependant, il semble manquer d'expérience spécifique dans la gestion des stocks et approvisionnements."}, 'Compétences techniques': {'score': 4, 'justification': "Le candidat dispose de compétences techniques solides dans la gestion de parcs bureautiques, de flottes mobiles, le diagnostic et la résolution de problèmes, ainsi que dans l'utilisation d'outils tels que SCCM, GLPI, ServiceNow, Active Directory, etc. Cependant, il semble manquer d'expérience dans la gestion des approvisionnements, des mises au rebut et la rédaction de procédures."}, 'Connaissance du domaine fonctionnel': {'score': 3, 'justification': "Le candidat possède une expérience significative en tant que technicien informatique, couvrant de nombreux aspects du domaine fonctionnel attendu. Cependant, il manque d'expérience spécifique dans la gestion des stocks et approvisionnements, ainsi que dans la participation à des projets de gestion de site."}, "Expériences similaires en accompagnement au changement, actions pédagogiques illustrant la capacité d'écoute, de reformulation et de synthèse": {'score': 3, 'justification': "Le CV montre des expériences pertinentes en formation d'équipes, rédaction de procédures et tutoriels, ainsi qu'en assistance et conseil aux utilisateurs, ce qui implique probablement des capacités d'écoute et de reformulation. Cependant, il manque des détails spécifiques sur l'accompagnement au changement et les actions pédagogiques illustrant explicitement ces capacités."}}
# <class 'dict'>
# {'Qualité de la réponse (Compréhension du besoin, le cas échéant outils et méthodologie proposés)': {'score': 3, 'justification': "Le candidat possède une expérience pertinente dans la gestion de parcs bureautiques et de flottes mobiles, ainsi que dans l'utilisation d'outils tels que ServiceNow, SCCM, GLPI, etc. Cependant, son CV ne mentionne pas spécifiquement sa compréhension des besoins de cette mission particulière de la SNCF ni la méthodologie ou les outils qu'il proposerait."}, 'Nombre et pertinence des expériences similaires': {'score': 5, 'justification': "Le candidat possède une expérience significative et pertinente dans la gestion des incidents, du matériel bureautique, de l'assistance aux utilisateurs et de la gestion des flottes mobiles, qui sont des aspects clés de la mission. Son expérience avec les outils ITSM, de déploiement et de gestion des flottes mobiles est un atout majeur. Cependant, il semble manquer d'expérience spécifique dans la gestion des stocks et approvisionnements."}, 'Compétences techniques': {'score': 4, 'justification': "Le candidat dispose de compétences techniques solides dans la gestion de parcs bureautiques, de flottes mobiles, le diagnostic et la résolution de problèmes, ainsi que dans l'utilisation d'outils tels que SCCM, GLPI, ServiceNow, Active Directory, etc. Cependant, il semble manquer d'expérience dans la gestion des approvisionnements, des mises au rebut et la rédaction de procédures."}, 'Connaissance du domaine fonctionnel': {'score': 3, 'justification': "Le candidat possède une expérience significative en tant que technicien informatique, couvrant de nombreux aspects du domaine fonctionnel attendu. Cependant, il manque d'expérience spécifique dans la gestion des stocks et approvisionnements, ainsi que dans la participation à des projets de gestion de site."}, "Expériences similaires en accompagnement au changement, actions pédagogiques illustrant la capacité d'écoute, de reformulation et de synthèse": {'score': 3, 'justification': "Le CV montre des expériences pertinentes en formation d'équipes, rédaction de procédures et tutoriels, ainsi qu'en assistance et conseil aux utilisateurs, ce qui implique probablement des capacités d'écoute et de reformulation. Cependant, il manque des détails spécifiques sur l'accompagnement au changement et les actions pédagogiques illustrant explicitement ces capacités."}}
# {'Qualité de la réponse (Compréhension du besoin, le cas échéant outils et méthodologie proposés)': {'score': 4, 'justification': "Le candidat démontre une bonne compréhension des besoins techniques de la mission grâce à son expérience pertinente dans la gestion de flottes mobiles, de parcs informatiques, la résolution d'incidents et le support aux utilisateurs. Cependant, certains aspects comme la gestion des stocks, la rédaction de documentation et la participation à des mini-projets ne sont pas clairement abordés dans son CV."}, 'Nombre et pertinence des expériences similaires': {'score': 4, 'justification': "Le candidat possède une expérience pertinente et solide dans la gestion de flottes mobiles, le support bureautique, la résolution d'incidents et la gestion de l'Active Directory, qui correspondent bien aux exigences de la mission. Ses expériences chez L'Oréal, Schneider Electric et 20th Century Fox sont particulièrement pertinentes, avec des tâches telles que la gestion de flottes mobiles, la résolution d'incidents de niveau 1 et 2, l'assistance aux utilisateurs, l'enrôlement mobile et le brassage réseau. Cependant, son expérience chez Prolival en tant que Technicien HelpDesk semble moins pertinente, et son projet personnel en cours n'apporte pas d'expérience supplémentaire pertinente."}, 'Compétences techniques': {'score': 5, 'justification': "Le candidat possède une expérience solide dans la gestion de flottes mobiles (Android, iOS), la résolution d'incidents de niveau 1 et 2, et l'environnement Active Directory/VPN, qui sont des compétences techniques clés pour cette mission. Cependant, il n'a pas d'expérience spécifique mentionnée avec O365 ou la gestion de stocks et d'approvisionnement. Malgré ces lacunes, ses compétences techniques couvrent une grande partie des exigences de la mission."}, 'Connaissance du domaine fonctionnel': {'score': 4, 'justification': "Le candidat possède une expérience pertinente en tant que technicien support bureautique et mobilité, avec une bonne connaissance de la gestion des flottes mobiles, de la résolution d'incidents, du support aux utilisateurs et de la gestion de l'Active Directory. Cependant, son expérience ne couvre pas certains aspects spécifiques de la mission, comme la gestion des stocks et des équipements, la rédaction de documentation et la participation à des projets liés à la gestion du site."}, "Expériences similaires en accompagnement au changement, actions pédagogiques illustrant la capacité d'écoute, de reformulation et de synthèse": {'score': 2, 'justification': "Le CV montre des expériences pertinentes en termes d'assistance aux utilisateurs et de résolution de problèmes, ce qui implique probablement des capacités d'écoute et de reformulation. Cependant, il n'y a pas d'exemples concrets d'actions pédagogiques ou d'accompagnement au changement, ni de détails sur des tâches de rédaction de documentation illustrant les capacités de synthèse."}}
# <class 'dict'>
# {'Qualité de la réponse (Compréhension du besoin, le cas échéant outils et méthodologie proposés)': {'score': 4, 'justification': "Le candidat démontre une bonne compréhension des besoins techniques de la mission grâce à son expérience pertinente dans la gestion de flottes mobiles, de parcs informatiques, la résolution d'incidents et le support aux utilisateurs. Cependant, certains aspects comme la gestion des stocks, la rédaction de documentation et la participation à des mini-projets ne sont pas clairement abordés dans son CV."}, 'Nombre et pertinence des expériences similaires': {'score': 4, 'justification': "Le candidat possède une expérience pertinente et solide dans la gestion de flottes mobiles, le support bureautique, la résolution d'incidents et la gestion de l'Active Directory, qui correspondent bien aux exigences de la mission. Ses expériences chez L'Oréal, Schneider Electric et 20th Century Fox sont particulièrement pertinentes, avec des tâches telles que la gestion de flottes mobiles, la résolution d'incidents de niveau 1 et 2, l'assistance aux utilisateurs, l'enrôlement mobile et le brassage réseau. Cependant, son expérience chez Prolival en tant que Technicien HelpDesk semble moins pertinente, et son projet personnel en cours n'apporte pas d'expérience supplémentaire pertinente."}, 'Compétences techniques': {'score': 5, 'justification': "Le candidat possède une expérience solide dans la gestion de flottes mobiles (Android, iOS), la résolution d'incidents de niveau 1 et 2, et l'environnement Active Directory/VPN, qui sont des compétences techniques clés pour cette mission. Cependant, il n'a pas d'expérience spécifique mentionnée avec O365 ou la gestion de stocks et d'approvisionnement. Malgré ces lacunes, ses compétences techniques couvrent une grande partie des exigences de la mission."}, 'Connaissance du domaine fonctionnel': {'score': 4, 'justification': "Le candidat possède une expérience pertinente en tant que technicien support bureautique et mobilité, avec une bonne connaissance de la gestion des flottes mobiles, de la résolution d'incidents, du support aux utilisateurs et de la gestion de l'Active Directory. Cependant, son expérience ne couvre pas certains aspects spécifiques de la mission, comme la gestion des stocks et des équipements, la rédaction de documentation et la participation à des projets liés à la gestion du site."}, "Expériences similaires en accompagnement au changement, actions pédagogiques illustrant la capacité d'écoute, de reformulation et de synthèse": {'score': 2, 'justification': "Le CV montre des expériences pertinentes en termes d'assistance aux utilisateurs et de résolution de problèmes, ce qui implique probablement des capacités d'écoute et de reformulation. Cependant, il n'y a pas d'exemples concrets d'actions pédagogiques ou d'accompagnement au changement, ni de détails sur des tâches de rédaction de documentation illustrant les capacités de synthèse."}}
# {'Qualité de la réponse (Compréhension du besoin, le cas échéant outils et méthodologie proposés)': {'score': 3, 'justification': 'Le candidat semble avoir une bonne compréhension générale des besoins de la mission grâce à son expérience pertinente dans la gestion de parcs bureautiques, de flottes mobiles et de stocks. Cependant, certains aspects spécifiques comme Active Directory/VPN, la gestion de demandes via un portail interne et les actions de communication/pédagogie ne sont pas directement abordés dans son CV. Par rapport aux autres candidats qui ont une expérience plus ciblée sur ces aspects, sa note a été légèrement diminuée.'}, 'Nombre et pertinence des expériences similaires': {'score': 4, 'justification': "Avec plus de 15 ans d'expérience dans des rôles similaires, le candidat se démarque nettement des autres. Bien qu'il manque peut-être un peu d'expérience spécifique avec les flottes mobiles Android/iOS et l'environnement O365/Active Directory/VPN requis, sa longue expérience dans des rôles équivalents compense largement ce manque. Sa note initiale a donc été maintenue."}, 'Compétences techniques': {'score': 3, 'justification': "Le candidat dispose d'une solide expérience dans le support technique, la gestion de parcs informatiques et l'assistance aux utilisateurs, ce qui correspond aux principales exigences de la mission. Ses certifications ITIL démontrent également ses compétences dans la gestion des services IT. Cependant, le CV ne mentionne pas explicitement d'expérience avec les flottes mobiles Android et iOS, qui font partie intégrante de la mission. De plus, bien que le candidat ait une expérience avec O365 et Active Directory, il n'est pas précisé s'il a travaillé dans un contexte spécifique de VPN, comme requis dans la mission. Par rapport aux autres candidats qui semblent avoir une expérience plus solide dans ces domaines, sa note a été légèrement diminuée."}, 'Connaissance du domaine fonctionnel': {'score': 4, 'justification': "Le candidat possède une expérience significative dans la gestion des services bureautiques et digitaux, notamment la gestion des demandes et incidents, l'assistance aux utilisateurs, la gestion des parcs et des stocks, ainsi que la rédaction de procédures et le conseil sur les outils. Son expérience semble cependant un peu moins axée sur la gestion des approvisionnements et des mises au rebut, qui est un aspect important de la mission. Globalement, son CV correspond très bien au critère d'évaluation grâce à sa vaste expertise acquise dans des rôles similaires. Sa note initiale a donc été maintenue."}, "Expériences similaires en accompagnement au changement, actions pédagogiques illustrant la capacité d'écoute, de reformulation et de synthèse": {'score': 3, 'justification': "Le candidat a une expérience pertinente en gestion d'équipes techniques, rédaction de documentation et accompagnement des utilisateurs. Cependant, il manque des exemples spécifiques démontrant ses capacités d'écoute, de reformulation et de synthèse dans un contexte d'accompagnement au changement de grande envergure. Par rapport à d'autres candidats qui semblent avoir une expérience plus solide dans ce domaine, sa note a été légèrement diminuée."}}
# <class 'dict'>
# {'Qualité de la réponse (Compréhension du besoin, le cas échéant outils et méthodologie proposés)': {'score': 3, 'justification': 'Le candidat semble avoir une bonne compréhension générale des besoins de la mission grâce à son expérience pertinente dans la gestion de parcs bureautiques, de flottes mobiles et de stocks. Cependant, certains aspects spécifiques comme Active Directory/VPN, la gestion de demandes via un portail interne et les actions de communication/pédagogie ne sont pas directement abordés dans son CV. Par rapport aux autres candidats qui ont une expérience plus ciblée sur ces aspects, sa note a été légèrement diminuée.'}, 'Nombre et pertinence des expériences similaires': {'score': 4, 'justification': "Avec plus de 15 ans d'expérience dans des rôles similaires, le candidat se démarque nettement des autres. Bien qu'il manque peut-être un peu d'expérience spécifique avec les flottes mobiles Android/iOS et l'environnement O365/Active Directory/VPN requis, sa longue expérience dans des rôles équivalents compense largement ce manque. Sa note initiale a donc été maintenue."}, 'Compétences techniques': {'score': 3, 'justification': "Le candidat dispose d'une solide expérience dans le support technique, la gestion de parcs informatiques et l'assistance aux utilisateurs, ce qui correspond aux principales exigences de la mission. Ses certifications ITIL démontrent également ses compétences dans la gestion des services IT. Cependant, le CV ne mentionne pas explicitement d'expérience avec les flottes mobiles Android et iOS, qui font partie intégrante de la mission. De plus, bien que le candidat ait une expérience avec O365 et Active Directory, il n'est pas précisé s'il a travaillé dans un contexte spécifique de VPN, comme requis dans la mission. Par rapport aux autres candidats qui semblent avoir une expérience plus solide dans ces domaines, sa note a été légèrement diminuée."}, 'Connaissance du domaine fonctionnel': {'score': 4, 'justification': "Le candidat possède une expérience significative dans la gestion des services bureautiques et digitaux, notamment la gestion des demandes et incidents, l'assistance aux utilisateurs, la gestion des parcs et des stocks, ainsi que la rédaction de procédures et le conseil sur les outils. Son expérience semble cependant un peu moins axée sur la gestion des approvisionnements et des mises au rebut, qui est un aspect important de la mission. Globalement, son CV correspond très bien au critère d'évaluation grâce à sa vaste expertise acquise dans des rôles similaires. Sa note initiale a donc été maintenue."}, "Expériences similaires en accompagnement au changement, actions pédagogiques illustrant la capacité d'écoute, de reformulation et de synthèse": {'score': 3, 'justification': "Le candidat a une expérience pertinente en gestion d'équipes techniques, rédaction de documentation et accompagnement des utilisateurs. Cependant, il manque des exemples spécifiques démontrant ses capacités d'écoute, de reformulation et de synthèse dans un contexte d'accompagnement au changement de grande envergure. Par rapport à d'autres candidats qui semblent avoir une expérience plus solide dans ce domaine, sa note a été légèrement diminuée."}}
# {'Qualité de la réponse (Compréhension du besoin, le cas échéant outils et méthodologie proposés)': {'score': 3, 'justification': "Le candidat a une expérience pertinente en tant que Team Leader et Coordinateur informatique, ce qui démontre une compréhension des besoins liés à la gestion d'équipes et de projets. Cependant, son CV ne mentionne pas explicitement les outils ou méthodologies spécifiques qu'il proposerait pour répondre à ce besoin particulier."}, 'Nombre et pertinence des expériences similaires': {'score': 5, 'justification': "Le candidat possède une expérience très riche et pertinente de plus de 15 ans dans des rôles liés au support technique, à la gestion de parc informatique et à l'assistance aux utilisateurs. Ses expériences couvrent des environnements techniques similaires à ceux mentionnés dans la mission. Comparé aux autres candidats, son expérience est parmi les plus pertinentes."}, 'Compétences techniques': {'score': 3, 'justification': "Le candidat dispose d'une solide expérience dans la gestion des stocks, des approvisionnements, des remises d'équipements, la rédaction de procédures et la participation à des projets liés à la gestion de sites. Il a également une bonne connaissance de l'environnement Microsoft et de la gestion de flottes mobiles. Cependant, son expérience avec O365 et les environnements Mac n'est pas clairement mentionnée. Par rapport aux autres candidats, ses compétences techniques sont correctes mais légèrement inférieures à certains autres."}, 'Connaissance du domaine fonctionnel': {'score': 5, 'justification': "Le candidat possède une expérience significative et pertinente dans le domaine fonctionnel requis pour la mission. Son parcours professionnel démontre une solide connaissance de la gestion des services bureautiques et digitaux, de l'assistance aux utilisateurs et de la gestion des équipements informatiques. Ses responsabilités couvrent directement les tâches attendues. Comparé aux autres candidats, sa connaissance du domaine fonctionnel semble être parmi les plus solides."}, "Expériences similaires en accompagnement au changement, actions pédagogiques illustrant la capacité d'écoute, de reformulation et de synthèse": {'score': 3, 'justification': "Le candidat possède une expérience significative en tant que Team Leader et dans des rôles impliquant la gestion d'équipe, la coordination du travail et la rédaction de procédures/tutoriels, ce qui démontre des capacités de synthèse et de reformulation. De plus, son expérience en tant que formateur/technicien de proximité illustre des actions pédagogiques et d'accompagnement des utilisateurs. Cependant, il n'y a pas de mention explicite de l'accompagnement au changement ni des capacités d'écoute dans les rôles décrits. Par rapport aux autres candidats, son expérience dans ce domaine semble similaire."}}
# <class 'dict'>
# {'Qualité de la réponse (Compréhension du besoin, le cas échéant outils et méthodologie proposés)': {'score': 3, 'justification': "Le candidat a une expérience pertinente en tant que Team Leader et Coordinateur informatique, ce qui démontre une compréhension des besoins liés à la gestion d'équipes et de projets. Cependant, son CV ne mentionne pas explicitement les outils ou méthodologies spécifiques qu'il proposerait pour répondre à ce besoin particulier."}, 'Nombre et pertinence des expériences similaires': {'score': 5, 'justification': "Le candidat possède une expérience très riche et pertinente de plus de 15 ans dans des rôles liés au support technique, à la gestion de parc informatique et à l'assistance aux utilisateurs. Ses expériences couvrent des environnements techniques similaires à ceux mentionnés dans la mission. Comparé aux autres candidats, son expérience est parmi les plus pertinentes."}, 'Compétences techniques': {'score': 3, 'justification': "Le candidat dispose d'une solide expérience dans la gestion des stocks, des approvisionnements, des remises d'équipements, la rédaction de procédures et la participation à des projets liés à la gestion de sites. Il a également une bonne connaissance de l'environnement Microsoft et de la gestion de flottes mobiles. Cependant, son expérience avec O365 et les environnements Mac n'est pas clairement mentionnée. Par rapport aux autres candidats, ses compétences techniques sont correctes mais légèrement inférieures à certains autres."}, 'Connaissance du domaine fonctionnel': {'score': 5, 'justification': "Le candidat possède une expérience significative et pertinente dans le domaine fonctionnel requis pour la mission. Son parcours professionnel démontre une solide connaissance de la gestion des services bureautiques et digitaux, de l'assistance aux utilisateurs et de la gestion des équipements informatiques. Ses responsabilités couvrent directement les tâches attendues. Comparé aux autres candidats, sa connaissance du domaine fonctionnel semble être parmi les plus solides."}, "Expériences similaires en accompagnement au changement, actions pédagogiques illustrant la capacité d'écoute, de reformulation et de synthèse": {'score': 3, 'justification': "Le candidat possède une expérience significative en tant que Team Leader et dans des rôles impliquant la gestion d'équipe, la coordination du travail et la rédaction de procédures/tutoriels, ce qui démontre des capacités de synthèse et de reformulation. De plus, son expérience en tant que formateur/technicien de proximité illustre des actions pédagogiques et d'accompagnement des utilisateurs. Cependant, il n'y a pas de mention explicite de l'accompagnement au changement ni des capacités d'écoute dans les rôles décrits. Par rapport aux autres candidats, son expérience dans ce domaine semble similaire."}}
# {'Qualité de la réponse (Compréhension du besoin, le cas échéant outils et méthodologie proposés)': {'score': 3, 'justification': "Le CV démontre une solide expérience en tant que consultant technicien support informatique, avec des compétences avérées dans la résolution d'incidents, l'installation/configuration de matériel et logiciels, la gestion de parcs, la migration Windows, etc. Le candidat a travaillé dans des environnements similaires à ceux requis pour la mission, notamment Windows, Android, iOS, Active Directory et VPN. Il a également de l'expérience dans la rédaction de procédures et la formation des utilisateurs. Cependant, le CV ne mentionne pas explicitement d'expérience dans la gestion des stocks et des approvisionnements, ni dans la rédaction de tutoriels et de consignes. Dans l'ensemble, le CV répond correctement au besoin, mais certains aspects pourraient être renforcés."}, 'Nombre et pertinence des expériences similaires': {'score': 4, 'justification': "Le candidat a une expérience significative et pertinente dans des rôles similaires de technicien support informatique et de gestion de parc informatique dans plusieurs grandes entreprises. Il a une expérience récente à la SNCF couvrant des tâches clés comme la gestion des sollicitations utilisateurs, le traitement des incidents, la gestion du parc informatique, la migration Windows 10 et la gestion des salles de crise. Il a également des expériences similaires chez d'autres grandes entreprises, couvrant un large éventail de tâches pertinentes. Cependant, il n'est pas clair s'il a géré des flottes mobiles ou des parcs bureautiques à grande échelle, et son expérience dans la gestion des stocks, de l'approvisionnement et de la mise au rebut n'est pas spécifiquement mentionnée."}, 'Compétences techniques': {'score': 3, 'justification': "Le candidat possède une solide expérience dans le support technique de niveau 2, la résolution d'incidents réseaux, matériels et logiciels, ainsi que l'installation, le paramétrage et la configuration de matériels informatiques. Il a une bonne connaissance des environnements Windows, des outils de gestion de parc, de l'Active Directory et de la gestion des VPN. Il a également travaillé sur des flottes mobiles Android et iOS, et a de l'expérience dans la gestion de stocks, de dotations et de retours d'équipements. Cependant, son expérience avec l'environnement bureautique O365 n'est pas clairement mentionnée, et son niveau d'expertise dans le diagnostic et la remédiation de problèmes sur les infrastructures réseau/VPN n'est pas évident. Son autonomie pour tenir le service en récurrent et alerter à bon escient n'est pas non plus clairement démontrée."}, 'Connaissance du domaine fonctionnel': {'score': 3, 'justification': "Le candidat possède une solide expérience dans le support technique informatique, couvrant de nombreux aspects liés à la gestion des sollicitations, l'assistance aux utilisateurs et la gestion des équipements. Il a acquis une bonne connaissance des environnements bureautiques, des flottes mobiles, des parcs Windows/Mac, ainsi que de l'Active Directory et des VPN. Cependant, son expérience dans la gestion des stocks, des approvisionnements et de la mise au rebut des équipements n'est pas clairement détaillée. De plus, son rôle dans la rédaction de procédures, tutoriels et consignes est peu mis en évidence dans son CV."}, "Expériences similaires en accompagnement au changement, actions pédagogiques illustrant la capacité d'écoute, de reformulation et de synthèse": {'score': 3, 'justification': "Le candidat a une expérience significative en assistance et accompagnement des utilisateurs lors de migrations et changements d'environnement informatique (Windows 7 à 10, déploiements, etc.). Il a également formé des utilisateurs sur les bonnes pratiques. Cependant, il n'y a pas de détails spécifiques sur des actions pédagogiques ou des méthodes d'écoute, de reformulation et de synthèse utilisées dans son CV. Son expérience r ...
# <class 'dict'>
# {'Qualité de la réponse (Compréhension du besoin, le cas échéant outils et méthodologie proposés)': {'score': 3, 'justification': "Le CV démontre une solide expérience en tant que consultant technicien support informatique, avec des compétences avérées dans la résolution d'incidents, l'installation/configuration de matériel et logiciels, la gestion de parcs, la migration Windows, etc. Le candidat a travaillé dans des environnements similaires à ceux requis pour la mission, notamment Windows, Android, iOS, Active Directory et VPN. Il a également de l'expérience dans la rédaction de procédures et la formation des utilisateurs. Cependant, le CV ne mentionne pas explicitement d'expérience dans la gestion des stocks et des approvisionnements, ni dans la rédaction de tutoriels et de consignes. Dans l'ensemble, le CV répond correctement au besoin, mais certains aspects pourraient être renforcés."}, 'Nombre et pertinence des expériences similaires': {'score': 4, 'justification': "Le candidat a une expérience significative et pertinente dans des rôles similaires de technicien support informatique et de gestion de parc informatique dans plusieurs grandes entreprises. Il a une expérience récente à la SNCF couvrant des tâches clés comme la gestion des sollicitations utilisateurs, le traitement des incidents, la gestion du parc informatique, la migration Windows 10 et la gestion des salles de crise. Il a également des expériences similaires chez d'autres grandes entreprises, couvrant un large éventail de tâches pertinentes. Cependant, il n'est pas clair s'il a géré des flottes mobiles ou des parcs bureautiques à grande échelle, et son expérience dans la gestion des stocks, de l'approvisionnement et de la mise au rebut n'est pas spécifiquement mentionnée."}, 'Compétences techniques': {'score': 3, 'justification': "Le candidat possède une solide expérience dans le support technique de niveau 2, la résolution d'incidents réseaux, matériels et logiciels, ainsi que l'installation, le paramétrage et la configuration de matériels informatiques. Il a une bonne connaissance des environnements Windows, des outils de gestion de parc, de l'Active Directory et de la gestion des VPN. Il a également travaillé sur des flottes mobiles Android et iOS, et a de l'expérience dans la gestion de stocks, de dotations et de retours d'équipements. Cependant, son expérience avec l'environnement bureautique O365 n'est pas clairement mentionnée, et son niveau d'expertise dans le diagnostic et la remédiation de problèmes sur les infrastructures réseau/VPN n'est pas évident. Son autonomie pour tenir le service en récurrent et alerter à bon escient n'est pas non plus clairement démontrée."}, 'Connaissance du domaine fonctionnel': {'score': 3, 'justification': "Le candidat possède une solide expérience dans le support technique informatique, couvrant de nombreux aspects liés à la gestion des sollicitations, l'assistance aux utilisateurs et la gestion des équipements. Il a acquis une bonne connaissance des environnements bureautiques, des flottes mobiles, des parcs Windows/Mac, ainsi que de l'Active Directory et des VPN. Cependant, son expérience dans la gestion des stocks, des approvisionnements et de la mise au rebut des équipements n'est pas clairement détaillée. De plus, son rôle dans la rédaction de procédures, tutoriels et consignes est peu mis en évidence dans son CV."}, "Expériences similaires en accompagnement au changement, actions pédagogiques illustrant la capacité d'écoute, de reformulation et de synthèse": {'score': 3, 'justification': "Le candidat a une expérience significative en assistance et accompagnement des utilisateurs lors de migrations et changements d'environnement informatique (Windows 7 à 10, déploiements, etc.). Il a également formé des utilisateurs sur les bonnes pratiques. Cependant, il n'y a pas de détails spécifiques sur des actions pédagogiques ou des méthodes d'écoute, de reformulation et de synthèse utilisées dans son CV. Son expérience r ...
# [{'critere': ['Qualité de la réponse (Compréhension du besoin, le cas échéant outils et méthodologie proposés)', 1], 'ponderation': [10, 1]}, {'critere': ['Nombre et pertinence des expériences similaires', 1], 'ponderation': [30, 1]}, {'critere': ['Compétences techniques', 1], 'ponderation': [30, 1]}, {'critere': ['Connaissance du domaine fonctionnel', 1], 'ponderation': [20, 1]}, {'critere': ["Expériences similaires en accompagnement au changement, actions pédagogiques illustrant la capacité d'écoute, de reformulation et de synthèse", 1], 'ponderation': [10, 1]}]
# Note technique : 3.4000000000000004
# Note technique : 2.9000000000000004
# Note technique : 3.9000000000000004
# Note technique : 4.1000000000000005
# Note technique : 3.5
# Note technique : 4.0
# Note technique : 3.3

# %%
dict_loaded = json.loads(json.dumps(
    
    {
    'Compétences techniques': {
        'justification': "Le candidat dispose d'une expérience solide de plus de 15 ans dans des postes de technicien informatique, avec une connaissance approfondie des environnements Windows, Mac, Android et iOS. Il maîtrise les outils de gestion de parc comme SCCM, GLPI et ServiceNow, et a une expérience dans la gestion des incidents, des stocks et des licences. Il a démontré sa capacité à travailler de manière autonome et à alerter en cas de besoin. Cependant, son CV ne mentionne pas d'expérience spécifique dans la gestion des approvisionnements et des mises au rebut, ce qui pourrait être un point faible par rapport aux exigences de la mission.",
        'score': 4
    }
}
))

# %%
dict_loaded
# Out:
# {'Compétences techniques': {'justification': "Le candidat dispose d'une expérience solide de plus de 15 ans dans des postes de technicien informatique, avec une connaissance approfondie des environnements Windows, Mac, Android et iOS. Il maîtrise les outils de gestion de parc comme SCCM, GLPI et ServiceNow, et a une expérience dans la gestion des incidents, des stocks et des licences. Il a démontré sa capacité à travailler de manière autonome et à alerter en cas de besoin. Cependant, son CV ne mentionne pas d'expérience spécifique dans la gestion des approvisionnements et des mises au rebut, ce qui pourrait être un point faible par rapport aux exigences de la mission.",
#   'score': 4}}

# %%
type(dict_loaded)
# Out:
# dict

# %%
# Create a dictionary to store the aggregated scores
aggregated_scores = 0
criteria_scores = formated_json_response
criteria_weights = CRITERIAS
# Iterate through each criterion and its weight
for criterion in criteria_weights:
    critere_name = criterion['critere'][0]
    weight = criterion['ponderation'][0] / 100

    # Iterate through the scores and justifications
    for key, value in criteria_scores.items():
        if key == critere_name:
            # Aggregate the weighted score
            aggregated_scores += value['score'] * (weight)

print(f"Note technique : {aggregated_scores}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 # Create a dictionary to store the aggregated scores
#       2 aggregated_scores = 0
# ----> 3 criteria_scores = formated_json_response
#       4 criteria_weights = CRITERIAS
#       5 # Iterate through each criterion and its weight
#
# NameError: name 'formated_json_response' is not defined
