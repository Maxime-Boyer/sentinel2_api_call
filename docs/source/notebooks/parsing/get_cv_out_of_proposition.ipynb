# %%
from dag_nao.modules.readers.pdf_reader import TextReader

# %%
T = TextReader()

# %%
proposition_pdf = "/workspace/data/03-AppelsOffre-anonyme/2023DOS0146516 - Assistance MOA SI Services FM/offres_techniques/NEURONES-1206980/proposition_technique.pdf"

proposition_text = T.get_info(proposition_pdf)

# %%
print(proposition_text)
# Out:
# DEBUT DE LA PAGE 1
#
#
#
#
#
#
#
#
#
# COMPÉTENCE MÉTIER
#
# -
# SI Immobilier
# -
# Management
# -
# Gestion du
# changement
# -
# Direction de projets
# -
# Développement
# Solutions logicielles
#
# MÉTHODOLOGIES
#
# -
# Cycle en V
# -
# Cadrage du besoin
# métier
# -
# SCRUM / AGILE
# OUTILS & PROGICIELS
#
# -
# WINDEV WEBDEV
# -
# PHP CSS
# -
# SLQ Server
# -
# Oracle
# -
# Power BI
#
# FORMATION
#
# -
# 1993   Langage C sous
# Unix
#
# -
# 1984   DUT Analyste
# Programmeur en
# Informatique de
# Gestion
#
#
# -
# 1983   DUT
# Programmeur en
# micro-informatique
#
# -
# 1982   Bac D
# (Mathématiques et
# Sciences de la nature)
#
#
# Chef de projet AMOA
# JCF
#  Senior avec 29 ans d’expérience
#   Français/ Anglais / Portugais / Espagnol
# COHERENCE DU PROFIL ET SYNTHESE DE MISSION
# SIGNIFICATIVE
#
# Nous avons le plaisir de vous proposer le profil JCF (sous-traitant
# indépendant) qui semble avoir les compétences en accord
# ...
